# %%
import re
 
import requests
from bs4 import BeautifulSoup


class Webscraping:
    def parse_data(self,response):
        soup=BeautifulSoup(response.content,"html.parser")
        return soup

    def show(self):
        response=requests.get('https://play.google.com/store/apps/collection/cluster?gsr=SkFqGE5zWU1nUVlpYktxUnNlU0d1L0plY3c9PcICJAogChxjb20ua2luZy5jYW5keWNydXNoamVsbHlzYWdhEAcYCA%3D%3D:S:ANO1ljLnLAU')   
        return response

    def data(self,soup):
        link_list,c=[],0

        for data in soup.find_all('div',class_="VfPpkd-EScbFb-JIbuQc UVEnyf"):
            link=soup.find_all('a')

            for i in link:
                print(c,"--------------------",i.text)
                c=c+1

            break
        
        #     link=data.find_all('a',class_="Si6A0c ZD8Cqc")
        #     link_list.append(link)
        # c=0
        # for link in link_list:
        #     print(c,"-----------------------",link)
        #     c+=1

wb=Webscraping()
get=wb.show()

new_get=wb.parse_data(get)
wb.data(new_get) 

# data=wb.parse_data(get)
# print(data(data))
# Out:
# 0 -------------------- google_logo Play
# 1 -------------------- Privacy Policy
# 2 -------------------- Terms of Service
# 3 -------------------- Games
# 4 -------------------- Apps
# 5 -------------------- Movies & TV
# 6 -------------------- Books
# 7 -------------------- Kids
# 8 -------------------- Candy Crush Friends Saga4.7star
# 9 -------------------- Candy Crush Soda Saga4.6star
# 10 -------------------- Farm Heroes Saga4.7star
# 11 -------------------- Candy Charming - Match 3 Games4.8star
# 12 -------------------- Sugar Hunter®: Match 3 Puzzle4.6star
# 13 -------------------- Candy Fever4.5star
# 14 -------------------- Candy Friends® : Match 34.7star
# 15 -------------------- Candy Sweet Legend - Match 34.6star
# 16 -------------------- Cookie Mania - Sweet Match 34.6star
# 17 -------------------- Candy Go Round - Sweet Puzzle Match 3 Game4.6star
# 18 -------------------- Jelly Drops - Puzzle Game4.8star
# 19 -------------------- Sweet Fruit Candy4.6star
# ...

# %%
import re
 
import requests
from bs4 import BeautifulSoup


class Webscraping:
    def parse_data(self,response):
        soup=BeautifulSoup(response.content,"html.parser")
        return soup

    def show(self):
        response=requests.get("https://play.google.com/store/apps/collection/cluster?gsr=SjxqGDEwbGhTNnFuMlRIN1V3R0w2QklnaVE9PcICHwobChdjb20ua2luZy5jYW5keWNydXNoc2FnYRAHGAg%3D:S:ANO1ljJUOFU")
        return response

    def data(self,soup):
        link_list,c=[],0

        for data in soup.find_all('div',class_="ftgkle"):
            link=soup.find_all('a')

            for i in link:
                print(c,"--------------------",i.text)
                c=c+1

            break
        
        

wb=Webscraping()
get=wb.show()

new_get=wb.parse_data(get)
wb.data(new_get) 

# data=wb.parse_data(get)
# print(data(data))
# Out:
# 0 -------------------- google_logo Play
# 1 -------------------- Privacy Policy
# 2 -------------------- Terms of Service
# 3 -------------------- Games
# 4 -------------------- Apps
# 5 -------------------- Movies & TV
# 6 -------------------- Books
# 7 -------------------- Kids
# 8 -------------------- Candy Crush Soda Saga4.6star
# 9 -------------------- Sweet Fruit Candy4.6star
# 10 -------------------- Candy Crush Friends Saga4.7star
# 11 -------------------- Candy Crush Jelly Saga4.6star
# 12 -------------------- Ludo King™4.3star
# 13 -------------------- Farm Heroes Saga4.7star
# 14 -------------------- Candy Fever4.5star
# 15 -------------------- 8 Ball Pool4.5star
# 16 -------------------- Bubble Shooter4.4star
# 17 -------------------- Bubble Shooter4.4star
# 18 -------------------- Fruit Block - Puzzle Legend4.5star
# 19 -------------------- Candy Sweet Garden4.5star
# 20 -------------------- Sand Balls - Puzzle Game4.3star
# ...
