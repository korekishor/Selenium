# %% [markdown]
# import requests

# %%
import requests
r = requests.get('https://api.github.com/events', stream=True)

r.raw
# <urllib3.response.HTTPResponse object at 0x101194810>

r.raw.read(10)
# '\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %%
import requests
r=requests.get('https://www.w3schools.com/python/module_requests.asp')
print(dir(r))
print(help(r))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
# ...

# %%
# text got all deta in html format
print(r.text)
# print(r.content) # got deta in irregular manar in html format

f=open('C:\\Users\\Kishor Kore\\Desktop\\request\\data_from_web.txt','r+')
f.write(r.text)
f.close()
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Python Requests Module</title>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="Keywords" content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C, C++, C#, jQuery, Bootstrap, Colors, W3.CSS, XML, MySQL, Icons, NodeJS, React, Graphics, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Exercises, Courses, Lessons, References, Examples, Learn to code, Source code, Demos, Tips, Website">
# <meta name="Description" content="Well organized and easy to understand Web building tutorials with lots of examples of how to use HTML, CSS, JavaScript, SQL, Python, PHP, Bootstrap, Java, XML and more.">
# <meta property="og:image" content="https://www.w3schools.com/images/w3schools_logo_436_2.png">
# <meta property="og:image:type" content="image/png">
# <meta property="og:image:width" content="436">
# ...

# %%
r=requests.get('https://www.google.com/imgres?imgurl=https%3A%2F%2Fimg.freepik.com%2Ffree-vector%2Fshining-circle-purple-lighting-isolated-dark-background_1441-2396.jpg%3Fw%3D2000&imgrefurl=https%3A%2F%2Fwww.freepik.com%2Fvectors%2Fsparkle-png&tbnid=cDmGWSoBTy6STM&vet=12ahUKEwj5v5jVwNL4AhW3idgFHQd9CH8QMygAegUIARDeAQ..i&docid=3aCba7D7138gTM&w=2000&h=1500&q=png%20images&ved=2ahUKEwj5v5jVwNL4AhW3idgFHQd9CH8QMygAegUIARDeAQ')
with open('C:\\Users\Kishor Kore\\Desktop\\request\\img_from_web.png','wb') as f:
    f.write(r.content)
print(r.content)
# Out:
# b'<!doctype html><html lang="en-IN"><head> <script nonce="bDGi_XVkj_f7bFm3HCaR-A">(function(){window.google={kEI:\'FzG8YoPRGPTDjuMP_d-j-AE\',kEXPI:\'0,1359408,1710,2736032,17447,47345,4751,1842,29218,43181,19259,2297,53965,2403,82880,35534,5175,94380,13557,24269,12574,24254,3792,14602,12179,6213,7662,6355,17369,7427,2508,1453,22295,20569,867,8718,2772,1477,4798,427,1490,2803,975,6004,6164,298,751,69,1278,3524,162,1108,447,296,1080,10,268,480,644,5833,1964,4435,2235,1131,767,745,523,318,270,1657,1311,206,588,215,185,342,180,1935,2208,266,1240,5392588,3605,5607170,1221,1911,1117,634,2009,1424,1872,131,955,178,458,599,284,72,26,3886,231,169,777,319,409,1555,98,244,927,1203,1896,1450,1171,185,30,129,861,2452,394,253,2544,1399,22,84,22,107,416,1016,114,948,1108,1004,61,605,14,631,14,200,626,1459,2370,299,1217,403,1035,324,870,233,887,350,191,7,170,612,20,1203,355,122,643,878,261,717,1909,2645,30,277,276,37,3,955,160,99,14,453,190,875,133,3,1627,642,322,1323,102,320,200,109,137,739,133,109
# ...

# %%
print(r.status_code)
print(r.ok)  

# status_code returns a number that indicates the status (200 is OK, 404 is Not Found)


print(r.text)
print(r.content)
# Out:
# 200
# True
# ...

# %%
import requests
dict_data={'page':2,'count':25}
r=requests.get('https://httpbin.org/get',params=dict_data)
print(r.text)

# print(r)
# print(r.url)
# print(r.json())
# Out:
# {
#   "args": {
#     "count": "25",
#     "page": "2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.0",
#     "X-Amzn-Trace-Id": "Root=1-62bc3769-53d9ab663323d7ce1f066577"
#   },
#   "origin": "117.248.110.84",
#   "url": "https://httpbin.org/get?page=2&count=25"
# }

# %%
import requests
user_data={'UserName':'Kishor','Email':'Kishorkore1999@gmail.com'}
r=requests.post('https://httpbin.org/post',data=user_data)
print(r.text)
print(r.json())
print(r.cookies)
print(r.headers)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "Email": "Kishorkore1999@gmail.com",
#     "UserName": "Kishor"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "48",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.0",
#     "X-Amzn-Trace-Id": "Root=1-62bbf41e-03c555303b673a5b304206ef"
#   },
#   "json": null,
#   "origin": "117.248.110.84",
#   "url": "https://httpbin.org/post"
# }
#
# ...

# %%
# 2:12
# connection pooling
# international domain and UnicodeTranslateError
# elegent key value cookies

# %%
# making get request used to get data from server

import requests
r=requests.get('https://www.w3schools.com/python/module_requests.asp')
print(r)

# %%
import requests
cookies_data=dict(key='value' )
r=requests.post('https://httpbin.org/post',cookies=cookies_data)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Cookie": "key=value",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.0",
#     "X-Amzn-Trace-Id": "Root=1-62bbf5d0-59f72dfa70acdd24035b41f5"
#   },
#   "json": null,
#   "origin": "117.248.110.84",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests
r=requests.post('https://httpbin.org/headers')
print(r.headers)
# Out:
# {'Date': 'Wed, 29 Jun 2022 06:50:35 GMT', 'Content-Type': 'text/html', 'Content-Length': '178', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Allow': 'GET, HEAD, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
import requests

url = 'http://w3schools.com/python/demopage.htm'

#first, make a request without setting the 'allow_redirects' parameter to False:
x = requests.get(url)
print(x.text)

print("----------------")

#then, make a request with the 'allow_redirects' parameter set to False:
x = requests.get(url, allow_redirects=False)
print(x.text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>This is a Test Page</h1>
#
# </body>
# </html>
# ----------------
# <html>
# <head><title>301 Moved Permanently</title></head>
# <body>
# <center><h1>301 Moved Permanently</h1></center>
# </body>
# </html>

# %%
import requests

url = 'https://w3schools.com/python/demopage.php'

#to demonstrate the 'timeout' parameter, we set the timeout to 0.001 to guarantee that the connection will be timed out:
x = requests.get(url, timeout=1.001)

print(x.text)

# %%
from bs4 import BeautifulSoup
import requests
url="https://www.w3schools.com/css/"

response=requests.get(url)
print(response)
 

# print(html_content)
# Out:
# <Response [200]>

# %%
html_content=response.content
soup=BeautifulSoup(html_content,'html.parser')
print(soup.prettify()) # all data in html
# Out:
# <a class="w3-bar-item w3-button w3-hover-none w3-left w3-padding-16" href="https://www.w3schools.com" style="width:77px" title="Home">
# <i class="fa fa-logo ws-text-green ws-hover-text-green" style="position:relative;font-size:42px!important;"></i>
# </a>

# %%
print(soup.title)
print(soup.title.name)
print(soup.title.string)
print(soup.title.parent.name)
# Out:
# <title>CSS Tutorial</title>
# title
# CSS Tutorial
# head

# %%
print(soup.a)
print(soup.find('a'))
print(soup.find_all('a')) # all ancale tag
print(soup.find_all('h1'))
print(soup.find_all('title'))
# Out:
# <a class="w3-bar-item w3-button w3-hover-none w3-left w3-padding-16" href="https://www.w3schools.com" style="width:77px" title="Home">
# <i class="fa fa-logo ws-text-green ws-hover-text-green" style="position:relative;font-size:42px!important;"></i>
# </a>

# %%
 
for link in soup.find_all('a'):
     print(link.get('href'))

# %%
for image in soup.find_all('img'):
     print(image.get('src'))

# %%
import requests

response=requests.get("https://www.w3schools.com/css/")
# print(response.text)
soup=BeautifulSoup(html_content,'html.parser')
# print(soup)
# print(soup.prettify)
print(soup.find(class_="w3-col l10 m12"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Kishor Kore\Desktop\webscraping\.ipynb_checkpoints\python request-checkpoint.ipynb Cell 22 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/webscraping/.ipynb_checkpoints/python%20request-checkpoint.ipynb#ch0000021?line=2'>3</a> response=requests.get("https://www.w3schools.com/css/")
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/webscraping/.ipynb_checkpoints/python%20request-checkpoint.ipynb#ch0000021?line=3'>4</a> # print(response.text)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/webscraping/.ipynb_checkpoints/python%20request-checkpoint.ipynb#ch0000021?line=4'>5</a> soup=BeautifulSoup(html_content,'html.parser')
# ...

# %%
product=soup.find_all('div',class_="w3-col l10 m12")
print(product)
# Out:
# [<div class="w3-col l10 m12" id="main">
# <div id="mainLeaderboard" style="overflow:hidden;">
# <!-- MainLeaderboard-->
# <!--<pre>main_leaderboard, all: [728,90][970,90][320,50][468,60]</pre>-->
# <div id="adngin-main_leaderboard-0"></div>
# <!-- adspace leaderboard -->
# </div>
# <h1>CSS <span class="color_h1">Tutorial</span></h1>
# <div class="w3-clear nextprev">
# <a class="w3-left w3-btn" href="/default.asp">❮ Home</a>
# <a class="w3-right w3-btn" href="css_intro.asp">Next ❯</a>
# </div>
# <div class="w3-panel w3-info intro">
# <p>CSS is the language we use to style an HTML document.</p>
# <p>CSS describes how HTML elements should be displayed.</p>
# <p>This tutorial will teach you CSS from basic to advanced.</p>
# <a class="w3-btn w3-margin-bottom" href="css_intro.asp" style="font-size: 18px;padding-left:25px;padding-right:25px;font-family: 'Source Sans Pro', sans-serif;margin-top:6px;">Start learning CSS now »</a>
# </div>
# <hr/>
# <h2>Examples in Each Chapter</h2>
# ...

# %%
from bs4 import BeautifulSoup
import requests
url="https://www.w3schools.com/css/"

response=requests.get(url)
html_content=response.content
# soup=BeautifulSoup(response,'html-parser')
# print(html_content)

# %%
from bs4 import BeautifulSoup
import requests

response=requests.get("https://www.flipkart.com/camera-clp-store?ef_id=EAIaIQobChMIyKffmbnS-AIVf4NLBR3zwwK8EAAYASAAEgK5OPD_BwE:G:s&s_kwcid=AL!739!3!548022040799!e!!g!!flipkart%20camera&semcmpid=sem_7847244212_BU_Electronics_Text_electronicdevice_Camera_goog&gclid=EAIaIQobChMIyKffmbnS-AIVf4NLBR3zwwK8EAAYASAAEgK5OPD_BwE")
soup=BeautifulSoup(response.text )
 
prices,images=[],[]
for d in soup.find_all('div',attrs={'class':'_2nRPpA'}):
       
      price_get=d.find('div',attrs={'class':'_30jeq3 UMT9wN'})
      image_get=d.find('div',attrs={'class':'_396cs4  _3exPp9'})
   
      prices.append(price_get.string)
 
print(prices)
# Out:
# ['₹2,499', '₹739', '₹1,02,990', '₹57,154', '₹31,499']

# %%
titles,prices,images = [], [], []
url="https://www.flipkart.com/laptops/pr?sid=6bo,b5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_a7af3621-81e5-47d7-90d1-4f4dcd881d64_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics~Laptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y"
response=requests.get(url)
soup=BeautifulSoup(response.text )
for d in soup.find_all('div',attrs={'class':'_2kHMtA'}):
    title = d.find('div',attrs={'class':'_4rR01T'})
    price = d.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    image = d.find('img',attrs={'class':'_396cs4 _3exPp9'})
    titles.append(title.string)
    prices.append(price.string)
    images.append(image.get('src'))

print("title:",titles)
print("-----------------")
print("Price:",prices)
print("-----------------")
print("images:",images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Kishor Kore\Desktop\webscraping\.ipynb_checkpoints\python request-checkpoint.ipynb Cell 26 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/webscraping/.ipynb_checkpoints/python%20request-checkpoint.ipynb#ch0000025?line=0'>1</a> titles,prices,images = [], [], []
# ...

# %%
soup.body.b
len(soup.contents)
# 1
soup.contents[0].name
title_tag = soup.title
title_tag
# <title>The Dormouse's story</title>
title_tag.parent
# <head><title>The Dormouse's story</title></head>
# Out:
# <head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6e7580.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><meta content="noodp" name="robots"/><link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link
# ...

# %%
html_tag = soup.html
type(html_tag.parent)
# <class 'bs4.BeautifulSoup'>
# Out:
# bs4.BeautifulSoup

# %%
for tag in soup.find_all(True):
   print(tag.name)
# Out:
# html
# head
# link
# link
# link
# meta
# meta
# meta
# meta
# meta
# link
# link
# meta
# meta
# link
# link
# link
# link
# link
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# style
# script
# script
# script
# script
# script
# link
# title
# meta
# meta
# meta
# meta
# link
# meta
# meta
# script
# script
# body
# div
# div
# div
# div
# div
# div
# div
# div
# a
# img
# a
# span
# img
# div
# form
# div
# div
# input
# button
# svg
# g
# path
# path
# input
# input
# input
# input
# input
# ul
# div
# div
# div
# div
# a
# div
# a
# span
# div
# div
# div
# div
# div
# svg
# path
# div
# div
# div
# a
# svg
# path
# span
# div
# div
# div
# div
# div
# h1
# div
# div
# p
# a
# a
# a
# a
# p
# br
# div
# div
# div
# div
# section
# div
# div
# span
# div
# section
# div
# span
# div
# div
# span
# svg
# path
# a
# div
# div
# span
# svg
# path
# a
# div
# div
# span
# svg
# path
# a
# section
# div
# div
# ...

# %%
soup.find_all("title")
# [<title>The Dormouse's story</title>]

soup.find_all("p", "title")
# [<p class="title"><b>The Dormouse's story</b></p>]

soup.find_all("a")
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

soup.find_all(id="link2")
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

import re
match=re.findall("id",soup.text)
print(match)
# 'Once upon a time there were three little sisters; and their names were\n'
# Out:
# ['id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'id']

# %%
soup.find_all(class_=re.compile("itl"))
soup.find_all("p", class_="body strikeout")
soup.select("p.strikeout.body")
# [<p class="body strikeout"></p>]
soup.find_all(string="Elsie")
soup.find_all(string=["Tillie", "Elsie", "Lacie"])
# ['Elsie', 'Lacie', 'Tillie']

# %%
def is_the_only_string_within_a_tag(s):
    """Return True if this string is the only child of its parent tag."""
    return (s == s.parent.string)

soup.find_all(string=is_the_only_string_within_a_tag)
# ["The Dormouse's story", "The Dormouse's story", 'Elsie', 'Lacie', 'Tillie', '...']
#
# Out:
# ['#container {\n\t\t\theight: 100%;\n\t\t}',
#  'Camera | Buy Digital Cameras at an discount of Upto 80% | Flipkart Big Billion Days',
#  "if (/*@cc_on!@*/false) {\n\t\t\twindow.browserVersion = 'IE10';\n\t\t\tdocument.documentElement.className += ' ie10';\n\t\t}",
# ...

# %%
# The prettify() method will turn a Beautiful Soup parse tree into a nicely formatted Unicode string,
# with a separate line for each tag and each string:

# %%
 
markup = '<a href="http://example.com/">I linked to <i>example.com</i></a>'
soup = BeautifulSoup(markup, 'html.parser')
tag = soup.a

tag.clear()
tag
# Out:
# <a href="http://example.com/"></a>

# %%
list1=[(1,2,3),{11,11,22,33,33},{(10,20,30):{'vi':18}}]

for i in list1:
    if type(i) is dict:
        for j in i:
            for k in j:
                print(k)
# Out:
# 10
# 20
# 30
